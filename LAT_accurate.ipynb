# %% [markdown]
# ## CODE
# #### Imports

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import MyUtils
from importlib import reload
import UNet
import pickle
import seg_metrics.seg_metrics as sg
import pandas as pd

# %% [markdown]
# #### User Input Data

# %%
path_training_dataset = "D:\\Work\\Sarbazi\\data\\all_data_LAT\\training"
path_testing_dataset = "D:\\Work\\Sarbazi\\data\\all_data_LAT\\testing"
batch_size = 2
femur_locator = False
if femur_locator:
    # for femur locator
    image_shape = (1024//2, 1024//2)
    crop_enabled = False
    naugment = 1
else:
    # for accurate segmentation
    image_shape = (1024//2, 768//2)
    crop_enabled = True
    naugment = 4

# %% [markdown]
# #### Data Generation

# %%
MyUtils = reload(MyUtils)
training_data = MyUtils.DataGenerator(path_training_dataset, batch_size, image_shape, crop_enabled, naugment, True, True)
testing_data = MyUtils.DataGenerator(path_testing_dataset, batch_size, image_shape, crop_enabled, naugment, False, True)

# %%
batch_id = 0
sample_batch_image, sample_batch_mask = training_data.__getitem__(batch_id)
img_ids = training_data._get_image_ids(batch_id)
fig, ax = plt.subplots(sample_batch_image.shape[0], 2, figsize=(5, 30))
for i in range(sample_batch_image.shape[0]):
    ax[i, 0].imshow(sample_batch_image[i,:,:,0],cmap='gray')
    ax[i, 0].set_title(str(img_ids[i//naugment]).zfill(3))
    ax[i, 1].imshow(sample_batch_mask[i,:,:,0],cmap='gray')
    ax[i, 1].set_title(str(img_ids[i//naugment]).zfill(3))

# %% [markdown]
# #### Create U-Net

# %%
UNet = reload(UNet)
MyUtils = reload(MyUtils)
if femur_locator:
    UNetModel = UNet.create_UNet_locator((*image_shape,1), (*image_shape,1))
else:
    UNetModel = UNet.create_UNet_accurate((*image_shape,1), (*image_shape,1))
UNetModel.compile(optimizer=MyUtils.keras.optimizers.Adam(), loss=MyUtils.binary_cross_entropy_and_dice_coef_loss)
# UNetModel.summary(line_length=120)

# %%
UNetModel.fit(training_data, validation_data=testing_data, epochs=50, workers=10, verbose=1)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 2s 62ms/step - loss: 0.1072 - val_loss: 0.1206
# Epoch 2/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.1061 - val_loss: 0.1221
# Epoch 3/50
# 22/22 [==============================] - 1s 61ms/step - loss: 0.1052 - val_loss: 0.1204
# Epoch 4/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.1042 - val_loss: 0.1190
# Epoch 5/50
# 22/22 [==============================] - 1s 61ms/step - loss: 0.1035 - val_loss: 0.1189
# Epoch 6/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.1023 - val_loss: 0.1179
# Epoch 7/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.1018 - val_loss: 0.1199
# Epoch 8/50
# 22/22 [==============================] - 1s 61ms/step - loss: 0.1020 - val_loss: 0.1143
# Epoch 9/50
# 22/22 [==============================] - 1s 61ms/step - loss: 0.1020 - val_loss: 0.1115
# Epoch 10/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.1001 - val_loss: 0.1106
# Epoch 11/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0985 - val_loss: 0.1115
# Epoch 12/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0969 - val_loss: 0.1115
# Epoch 13/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0958 - val_loss: 0.1117
# Epoch 14/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0946 - val_loss: 0.1113
# Epoch 15/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0937 - val_loss: 0.1102
# Epoch 16/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0928 - val_loss: 0.1097
# Epoch 17/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0920 - val_loss: 0.1089
# Epoch 18/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0911 - val_loss: 0.1069
# Epoch 19/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0903 - val_loss: 0.1088
# Epoch 20/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0894 - val_loss: 0.1046
# Epoch 21/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0886 - val_loss: 0.1081
# Epoch 22/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0876 - val_loss: 0.1061
# Epoch 23/50
# 22/22 [==============================] - 2s 68ms/step - loss: 0.0870 - val_loss: 0.1043
# Epoch 24/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0861 - val_loss: 0.1021
# Epoch 25/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0852 - val_loss: 0.1024
# Epoch 26/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0844 - val_loss: 0.1030
# Epoch 27/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0838 - val_loss: 0.1017
# Epoch 28/50
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0831 - val_loss: 0.1017
# Epoch 29/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0821 - val_loss: 0.1026
# Epoch 30/50
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0814 - val_loss: 0.1006
# Epoch 31/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0807 - val_loss: 0.0987
# Epoch 32/50
# 22/22 [==============================] - 1s 64ms/step - loss: 0.0802 - val_loss: 0.0992
# Epoch 33/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0796 - val_loss: 0.0986
# Epoch 34/50
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0794 - val_loss: 0.0951
# Epoch 35/50
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0784 - val_loss: 0.0936
# Epoch 36/50
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0776 - val_loss: 0.0944
# Epoch 37/50
# 22/22 [==============================] - 1s 68ms/step - loss: 0.0773 - val_loss: 0.0914
# Epoch 38/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0776 - val_loss: 0.0903
# Epoch 39/50
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0770 - val_loss: 0.0961
# Epoch 40/50
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0758 - val_loss: 0.0887
# Epoch 41/50
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0744 - val_loss: 0.0914
# Epoch 42/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0736 - val_loss: 0.0934
# Epoch 43/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0728 - val_loss: 0.0914
# Epoch 44/50
# 22/22 [==============================] - 1s 61ms/step - loss: 0.0721 - val_loss: 0.0865
# Epoch 45/50
# 22/22 [==============================] - 1s 61ms/step - loss: 0.0712 - val_loss: 0.0902
# Epoch 46/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0705 - val_loss: 0.0876
# Epoch 47/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0698 - val_loss: 0.0874
# Epoch 48/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0691 - val_loss: 0.0874
# Epoch 49/50
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0686 - val_loss: 0.0876
# Epoch 50/50
# 22/22 [==============================] - 1s 67ms/step - loss: 0.0679 - val_loss: 0.0875

# %%
if femur_locator:
    UNetModel.save('UNetModel_locator_LAT.h5')
else:
    UNetModel.save('UNetModel_accurate_LAT.h5')

# %%
if coarse_network:
    UNetModel = UNet.keras_models.load_model('UNetModel_locator_LAT.h5', custom_objects={"dice_coef_loss": MyUtils.dice_coef_loss, "dice_coef": MyUtils.dice_coef, "binary_cross_entropy_and_dice_coef_loss": MyUtils.binary_cross_entropy_and_dice_coef_loss})
else:
    UNetModel = UNet.keras_models.load_model('UNetModel_accurate_LAT.h5', custom_objects={"dice_coef_loss": MyUtils.dice_coef_loss, "dice_coef": MyUtils.dice_coef, "binary_cross_entropy_and_dice_coef_loss": MyUtils.binary_cross_entropy_and_dice_coef_loss})

# %%
batch_id = 0
sample_test_image, sample_test_mask = testing_data.__getitem__(batch_id)
predict_segment = UNetModel.predict(sample_test_image)
predict_segment = (predict_segment>0.5).astype(np.bool_)

fig, axs = plt.subplots(sample_test_image.shape[0], 2, figsize=(8,40))
titles = [str(i).zfill(3) for i in testing_data._get_image_ids(batch_id)]
for i in range(sample_test_image.shape[0]):
    axs[i,0].imshow(sample_test_image[i,:,:,0], cmap='gray')
    axs[i,0].imshow(sample_test_mask[i,:,:,0],cmap='gray',alpha=0.5)
    axs[i,0].set_title("Image %s - Manual Segmentation" % (titles[i//naugment]))
    axs[i,0].axis('off')
    axs[i,1].imshow(sample_test_image[i,:,:,0], cmap='gray')
    axs[i,1].imshow(predict_segment[i,:,:,0],cmap='gray',alpha=0.5)
    axs[i,1].set_title("Image %s - U-Net Segmentation" % (titles[i//naugment]))
    axs[i,1].axis('off')
plt.subplots_adjust(hspace=0.1, wspace=0.1)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
# with open('out.png','wb') as f:
#     fig.savefig(f, dpi=600)

# %% [markdown]
# ## evaluation on selected dataset

# %%
eval_data = testing_data
gdth_img = []
pred_img = []
for i in range(len(eval_data)):
    images, masks = eval_data[i]
    predict_segment = UNetModel.predict(images, verbose=0)
    predict_segment = (predict_segment>0.5).astype(np.int_)
    for m in range(masks.shape[0]):
        gdth_img.append(masks[m,:,:,0])
        pred_img.append(predict_segment[m,:,:,0])
labels = [0, 1]
spacing = [0.3, 0.3]
metrics = sg.write_metrics(labels=labels[1:],  # exclude background if needed
                          gdth_img=gdth_img,
                          pred_img=pred_img,
                          spacing=spacing,
                          TPTNFPFN=True)
reshape_metrics = {} 
for m in metrics:
    for k in m.keys():
        try:
            reshape_metrics[k].append(m[k][0])
        except:
            reshape_metrics[k] = []
            reshape_metrics[k].append(m[k][0])


for k in reshape_metrics.keys():
    reshape_metrics[k] = np.array(reshape_metrics[k])

reshape_metrics["nfpr"] = reshape_metrics["FP"] / (reshape_metrics["TP"]+reshape_metrics["FN"])
n = reshape_metrics["TP"] + reshape_metrics["TN"] + reshape_metrics["FP"] + reshape_metrics["FN"]
fa = reshape_metrics["TP"]+reshape_metrics["TN"]
fc = (reshape_metrics["TN"]+reshape_metrics["FN"])*(reshape_metrics["TN"]+reshape_metrics["FP"]) + (reshape_metrics["FP"]+reshape_metrics["TP"])*(reshape_metrics["FN"]+reshape_metrics["TP"])
fc /= n
reshape_metrics["kap"] = (fa-fc)/(n-fc)
reshape_metrics["auc"] = 1-(reshape_metrics["fpr"]+reshape_metrics["fnr"])/2
reshape_metrics["acc"] = (reshape_metrics["TP"]+reshape_metrics["TN"])/n
reshape_metrics["inf"] = 1-reshape_metrics["fnr"]-reshape_metrics["fpr"]
ppv = reshape_metrics["TP"]/(reshape_metrics["TP"]+reshape_metrics["FP"])
npv = reshape_metrics["TN"]/(reshape_metrics["TN"]+reshape_metrics["FN"])
reshape_metrics["mk"] = ppv + npv - 1
reshape_metrics.pop("label")
reshape_metrics.pop("TP")
reshape_metrics.pop("TN")
reshape_metrics.pop("FP")
reshape_metrics.pop("FN")
# Out:
# 40it [00:09,  4.37it/s]
# array([ 146,   36,  103,   89,    0,    0,    0,    0,   16,    6,    2,
#          17,  470,   85,   27,   19, 4530,   84,  163,  963,   20,   23,
#          39,    0,   10,   43,    9,    6,   49,    1,    0,    2,   50,
#           5,   13,   51,    7,    0,    0,    0])

# %%
myorder_metrics = {}
for k in ["dice", "jaccard", "acc", "precision", "recall", "fpr", "fnr", "nfpr", "kap", "auc", "inf", "mk", "hd", "msd", "mdsd", "stdsd", "hd95"]:
    myorder_metrics[k] = reshape_metrics[k]
for k in myorder_metrics.keys():
    print("%s" % k)
for k in myorder_metrics.keys():
    print("%.2f \u00B1 %.2f" % (np.round(np.mean(myorder_metrics[k]), decimals=2), np.round(np.std(myorder_metrics[k]), decimals=2)))
# Out:
# dice
# jaccard
# acc
# precision
# recall
# fpr
# fnr
# nfpr
# kap
# auc
# inf
# mk
# hd
# msd
# mdsd
# stdsd
# hd95
# 0.97 ± 0.03
# 0.94 ± 0.05
# 0.99 ± 0.00
# 0.94 ± 0.05
# 1.00 ± 0.01
# 0.01 ± 0.00
# 0.00 ± 0.01
# 0.06 ± 0.07
# 0.96 ± 0.03
# 0.99 ± 0.01
# 0.98 ± 0.01
# 0.94 ± 0.05
# 5.15 ± 11.98
# 1.02 ± 2.91
# 0.51 ± 0.11
# 1.07 ± 4.16
# 2.78 ± 10.28

# %%
df = pd.DataFrame(myorder_metrics)
df.to_csv("locator_network_metrics.csv")
